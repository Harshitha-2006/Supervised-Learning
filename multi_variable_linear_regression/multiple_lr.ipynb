# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv("multiplelr.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         3   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000

# %%
lr=linear_model.LinearRegression()
lr.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
lr.intercept_
# Out:
# 383724.99999999977

# %%
lr.predict([[2600,3,20]])
# Out:
# array([526000.])

# %%
lr.predict([[2600,3,25]])
# Out:
# array([491875.])

# %%
#price=m1*area+m2*bedroom+m3*age+b
137.25*2600 -26025*3-6825*25+383724.99999999977
# Out:
# 491874.99999999977

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(df['area'],df['bedrooms'],df['price'],color='green')
ax.set_xlabel('Area')
ax.set_ylabel('Bedrooms')
ax.set_zlabel('Price')
plt.title('3D Plot')
plt.show()
